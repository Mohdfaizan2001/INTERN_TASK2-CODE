# %% [markdown]
# # TASK 2

# %%
import pandas as pd

# %%
task = pd.read_excel("C:\\Users\\mohdf\\Downloads\\ml al training\\Input_1.xlsx")

# %%
task
# Out:
#         Name  id Chapter Tag Concept Test 1 - score  \
# 0    Darshan  34       C8S11                      4
# 1      Durga  35       C8S11                      3
# 2      Idhaz  36       C8S11                      5
# 3    Kishore  37       C8S11                      1
# 4       Mano  38       C8S11                      4
# 5     Nandha  39       C8S11                      3
# 6   Nandhini  40       C8S11                      5
# 7     Rubika  42       C8S11                      2
# 8      Saila  43       C8S11                      -
# 9    Shankar  44       C8S11                      1
# 10     Tarun  45       C8S11                      3
# 11    Thanis  46       C8S11                      5
# 12   Vignesh  47       C8S11                      3
#
#    Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                    118                         4
# 1                                    886                         5
# ...

# %%
task.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 57 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Name                                        13 non-null     object
#  1   id                                          13 non-null     int64
#  2   Chapter Tag                                 13 non-null     object
#  3   Concept Test 1 - score                      13 non-null     object
#  4   Concept Test 1 - time-taken (seconds)       13 non-null     object
#  5   Concept Test 1 - answered                   13 non-null     object
#  6   Concept Test 1- correct                     13 non-null     object
#  7   Concept Test 1- wrong                       13 non-null     object
#  8   Concept Test 1- skipped                     13 non-null     object
#  9   Concept Test 2 - score                      13 non-null     object
# ...

# %%
task.columns
# Out:
# Index(['Name', 'id', 'Chapter Tag', 'Concept Test 1 - score',
#        'Concept Test 1 - time-taken (seconds)', 'Concept Test 1 - answered',
#        'Concept Test 1- correct', 'Concept Test 1- wrong',
#        'Concept Test 1- skipped', 'Concept Test 2 - score',
#        'Concept Test 2 - time-taken (seconds)', 'Concept Test 2 - answered',
#        'Concept Test 2- correct', 'Concept Test 2- wrong',
#        'Concept Test 2- skipped', 'Concept Test 3 - score',
#        'Concept Test 3 - time-taken (seconds)', 'Concept Test 3 - answered',
#        'Concept Test 3- correct', 'Concept Test 3- wrong',
#        'Concept Test 3- skipped', 'Concept Test 4 - score',
#        'Concept Test 4 - time-taken (seconds)', 'Concept Test 4 - answered',
#        'Concept Test 4- correct', 'Concept Test 4- wrong',
#        'Concept Test 4- skipped', 'Topic Test 1 - score',
#        'Topic Test 1 - time-taken (seconds)', 'Topic Test 1 - answered',
# ...

# %%
x=task[['Name','id','Chapter Tag','Concept Test 1 - answered','Concept Test 1- correct','Concept Test 1 - score','Concept Test 1- skipped','Concept Test 1 - time-taken (seconds)','Concept Test 1- wrong']]

# %%
x['Test Name']='Concept Test 1'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1834534762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Test Name']='Concept Test 1'

# %%
x
# Out:
#         Name  id Chapter Tag Concept Test 1 - answered  \
# 0    Darshan  34       C8S11                         4
# 1      Durga  35       C8S11                         5
# 2      Idhaz  36       C8S11                         5
# 3    Kishore  37       C8S11                         3
# 4       Mano  38       C8S11                         5
# 5     Nandha  39       C8S11                         5
# 6   Nandhini  40       C8S11                         5
# 7     Rubika  42       C8S11                         5
# 8      Saila  43       C8S11                         -
# 9    Shankar  44       C8S11                         5
# 10     Tarun  45       C8S11                         5
# 11    Thanis  46       C8S11                         5
# 12   Vignesh  47       C8S11                         5
#
#    Concept Test 1- correct Concept Test 1 - score Concept Test 1- skipped  \
# 0                        4                      4                       1
# ...

# %%
task1=pd.melt(x,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 1 - answered","Concept Test 1- correct","Concept Test 1 - score","Concept Test 1- skipped","Concept Test 1 - time-taken (seconds)"],value_name="Concept Test 1- wrong")
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1936700027.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task1=pd.melt(x,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 1 - answered","Concept Test 1- correct","Concept Test 1 - score","Concept Test 1- skipped","Concept Test 1 - time-taken (seconds)"],value_name="Concept Test 1- wrong")

# %%
task1
# Out:
#         Name  id Chapter Tag       Test Name Concept Test 1 - answered  \
# 0    Darshan  34       C8S11  Concept Test 1                         4
# 1      Durga  35       C8S11  Concept Test 1                         5
# 2      Idhaz  36       C8S11  Concept Test 1                         5
# 3    Kishore  37       C8S11  Concept Test 1                         3
# 4       Mano  38       C8S11  Concept Test 1                         5
# 5     Nandha  39       C8S11  Concept Test 1                         5
# 6   Nandhini  40       C8S11  Concept Test 1                         5
# 7     Rubika  42       C8S11  Concept Test 1                         5
# 8      Saila  43       C8S11  Concept Test 1                         -
# 9    Shankar  44       C8S11  Concept Test 1                         5
# 10     Tarun  45       C8S11  Concept Test 1                         5
# 11    Thanis  46       C8S11  Concept Test 1                         5
# ...

# %%
task1=task1.rename(columns={'id':'Username','Concept Test 1 - score':'score','Concept Test 1 - answered':'answered','Concept Test 1- correct':'correct','Concept Test 1- wrong':'wrong','Concept Test 1- skipped':'skipped','Concept Test 1 - time-taken (seconds)':'time-taken'})

# %%
task1
# Out:
#         Name  Username Chapter Tag       Test Name answered correct score  \
# 0    Darshan        34       C8S11  Concept Test 1        4       4     4
# 1      Durga        35       C8S11  Concept Test 1        5       3     3
# 2      Idhaz        36       C8S11  Concept Test 1        5       5     5
# 3    Kishore        37       C8S11  Concept Test 1        3       1     1
# 4       Mano        38       C8S11  Concept Test 1        5       4     4
# 5     Nandha        39       C8S11  Concept Test 1        5       3     3
# 6   Nandhini        40       C8S11  Concept Test 1        5       5     5
# 7     Rubika        42       C8S11  Concept Test 1        5       2     2
# 8      Saila        43       C8S11  Concept Test 1        -       -     -
# 9    Shankar        44       C8S11  Concept Test 1        5       1     1
# 10     Tarun        45       C8S11  Concept Test 1        5       3     3
# 11    Thanis        46       C8S11  Concept Test 1        5       5     5
# ...

# %%
y=task[['Name','id','Chapter Tag','Concept Test 2 - answered','Concept Test 2- correct','Concept Test 2 - score','Concept Test 2- wrong','Concept Test 2- skipped','Concept Test 2 - time-taken (seconds)']]

# %%
y['Test Name']='Concept Test 2'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\2972748963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Test Name']='Concept Test 2'

# %%
y
# Out:
#         Name  id Chapter Tag Concept Test 2 - answered  \
# 0    Darshan  34       C8S11                         4
# 1      Durga  35       C8S11                         5
# 2      Idhaz  36       C8S11                         5
# 3    Kishore  37       C8S11                         -
# 4       Mano  38       C8S11                         5
# 5     Nandha  39       C8S11                         5
# 6   Nandhini  40       C8S11                         5
# 7     Rubika  42       C8S11                         5
# 8      Saila  43       C8S11                         5
# 9    Shankar  44       C8S11                         5
# 10     Tarun  45       C8S11                         5
# 11    Thanis  46       C8S11                         5
# 12   Vignesh  47       C8S11                         5
#
#    Concept Test 2- correct Concept Test 2 - score Concept Test 2- wrong  \
# 0                        1                      1                     3
# ...

# %%
task2=pd.melt(y,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 2 - answered","Concept Test 2- correct","Concept Test 2 - score","Concept Test 2- skipped","Concept Test 2 - time-taken (seconds)"],value_name='Concept Test 2- wrong')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\13781556.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task2=pd.melt(y,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 2 - answered","Concept Test 2- correct","Concept Test 2 - score","Concept Test 2- skipped","Concept Test 2 - time-taken (seconds)"],value_name='Concept Test 2- wrong')

# %%
task2
# Out:
#         Name  id Chapter Tag       Test Name Concept Test 2 - answered  \
# 0    Darshan  34       C8S11  Concept Test 2                         4
# 1      Durga  35       C8S11  Concept Test 2                         5
# 2      Idhaz  36       C8S11  Concept Test 2                         5
# 3    Kishore  37       C8S11  Concept Test 2                         -
# 4       Mano  38       C8S11  Concept Test 2                         5
# 5     Nandha  39       C8S11  Concept Test 2                         5
# 6   Nandhini  40       C8S11  Concept Test 2                         5
# 7     Rubika  42       C8S11  Concept Test 2                         5
# 8      Saila  43       C8S11  Concept Test 2                         5
# 9    Shankar  44       C8S11  Concept Test 2                         5
# 10     Tarun  45       C8S11  Concept Test 2                         5
# 11    Thanis  46       C8S11  Concept Test 2                         5
# ...

# %%
task2=task2.rename(columns={'id':'Username','Concept Test 2 - score':'score','Concept Test 2 - answered':'answered','Concept Test 2- correct':'correct','Concept Test 2- wrong':'wrong','Concept Test 2- skipped':'skipped','Concept Test 2 - time-taken (seconds)':'time-taken'})

# %%
task2
# Out:
#         Name  Username Chapter Tag       Test Name answered correct score  \
# 0    Darshan        34       C8S11  Concept Test 2        4       1     1
# 1      Durga        35       C8S11  Concept Test 2        5       3     3
# 2      Idhaz        36       C8S11  Concept Test 2        5       3     3
# 3    Kishore        37       C8S11  Concept Test 2        -       -     -
# 4       Mano        38       C8S11  Concept Test 2        5       0     0
# 5     Nandha        39       C8S11  Concept Test 2        5       0     0
# 6   Nandhini        40       C8S11  Concept Test 2        5       3     3
# 7     Rubika        42       C8S11  Concept Test 2        5       0     0
# 8      Saila        43       C8S11  Concept Test 2        5       0     0
# 9    Shankar        44       C8S11  Concept Test 2        5       1     1
# 10     Tarun        45       C8S11  Concept Test 2        5       2     2
# 11    Thanis        46       C8S11  Concept Test 2        5       2     2
# ...

# %%
z=task[['Name','id','Chapter Tag','Concept Test 3 - score','Concept Test 3 - answered','Concept Test 3- correct','Concept Test 3- wrong','Concept Test 3- skipped','Concept Test 3 - time-taken (seconds)']]

# %%
z['Test Name']='Concept Test 3'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\717891982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z['Test Name']='Concept Test 3'

# %%
task3=pd.melt(z,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 3 - score","Concept Test 3 - answered","Concept Test 3- correct","Concept Test 3- wrong","Concept Test 3- skipped"],value_name='Concept Test 3 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3112273660.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task3=pd.melt(z,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 3 - score","Concept Test 3 - answered","Concept Test 3- correct","Concept Test 3- wrong","Concept Test 3- skipped"],value_name='Concept Test 3 - time-taken (seconds)')

# %%
task3
# Out:
#         Name  id Chapter Tag       Test Name Concept Test 3 - score  \
# 0    Darshan  34       C8S11  Concept Test 3                      4
# 1      Durga  35       C8S11  Concept Test 3                      2
# 2      Idhaz  36       C8S11  Concept Test 3                      4
# 3    Kishore  37       C8S11  Concept Test 3                      -
# 4       Mano  38       C8S11  Concept Test 3                      1
# 5     Nandha  39       C8S11  Concept Test 3                      1
# 6   Nandhini  40       C8S11  Concept Test 3                      4
# 7     Rubika  42       C8S11  Concept Test 3                      2
# 8      Saila  43       C8S11  Concept Test 3                      -
# 9    Shankar  44       C8S11  Concept Test 3                      1
# 10     Tarun  45       C8S11  Concept Test 3                      -
# 11    Thanis  46       C8S11  Concept Test 3                      3
# 12   Vignesh  47       C8S11  Concept Test 3                      1
#
# ...

# %%
task3=task3.rename(columns={'id':'Username','Concept Test 3 - score':'score','Concept Test 3 - answered':'answered','Concept Test 3- correct':'correct','Concept Test 3- wrong':'wrong','Concept Test 3- skipped':'skipped','Concept Test 3 - time-taken (seconds)':'time-taken'})

# %%
task3
# Out:
#         Name  Username Chapter Tag       Test Name score answered correct  \
# 0    Darshan        34       C8S11  Concept Test 3     4        5       4
# 1      Durga        35       C8S11  Concept Test 3     2        5       2
# 2      Idhaz        36       C8S11  Concept Test 3     4        5       4
# 3    Kishore        37       C8S11  Concept Test 3     -        -       -
# 4       Mano        38       C8S11  Concept Test 3     1        5       1
# 5     Nandha        39       C8S11  Concept Test 3     1        5       1
# 6   Nandhini        40       C8S11  Concept Test 3     4        5       4
# 7     Rubika        42       C8S11  Concept Test 3     2        5       2
# 8      Saila        43       C8S11  Concept Test 3     -        -       -
# 9    Shankar        44       C8S11  Concept Test 3     1        5       1
# 10     Tarun        45       C8S11  Concept Test 3     -        -       -
# 11    Thanis        46       C8S11  Concept Test 3     3        5       3
# ...

# %%
p=task[['Name','id','Chapter Tag','Concept Test 4 - score','Concept Test 4 - answered','Concept Test 4- correct','Concept Test 4- wrong','Concept Test 4- skipped','Concept Test 4 - time-taken (seconds)']]

# %%
p['Test Name']='Concept Test 4'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\4099425134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['Test Name']='Concept Test 4'

# %%
task4=pd.melt(p,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 4 - score","Concept Test 4 - answered","Concept Test 4- correct","Concept Test 4- wrong","Concept Test 4- skipped"],value_name='Concept Test 4 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1387742175.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task4=pd.melt(p,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 4 - score","Concept Test 4 - answered","Concept Test 4- correct","Concept Test 4- wrong","Concept Test 4- skipped"],value_name='Concept Test 4 - time-taken (seconds)')

# %%
task4
# Out:
#         Name  id Chapter Tag       Test Name Concept Test 4 - score  \
# 0    Darshan  34       C8S11  Concept Test 4                      3
# 1      Durga  35       C8S11  Concept Test 4                      4
# 2      Idhaz  36       C8S11  Concept Test 4                      3
# 3    Kishore  37       C8S11  Concept Test 4                      0
# 4       Mano  38       C8S11  Concept Test 4                      2
# 5     Nandha  39       C8S11  Concept Test 4                      1
# 6   Nandhini  40       C8S11  Concept Test 4                      5
# 7     Rubika  42       C8S11  Concept Test 4                      3
# 8      Saila  43       C8S11  Concept Test 4                      -
# 9    Shankar  44       C8S11  Concept Test 4                      1
# 10     Tarun  45       C8S11  Concept Test 4                      3
# 11    Thanis  46       C8S11  Concept Test 4                      1
# 12   Vignesh  47       C8S11  Concept Test 4                      2
#
# ...

# %%
task4=task4.rename(columns={'id':'Username','Concept Test 4 - score':'score','Concept Test 4 - answered':'answered','Concept Test 4- correct':'correct','Concept Test 4- wrong':'wrong','Concept Test 4- skipped':'skipped','Concept Test 4 - time-taken (seconds)':'time-taken'})

# %%
task4
# Out:
#         Name  Username Chapter Tag       Test Name score answered correct  \
# 0    Darshan        34       C8S11  Concept Test 4     3        5       3
# 1      Durga        35       C8S11  Concept Test 4     4        5       4
# 2      Idhaz        36       C8S11  Concept Test 4     3        5       3
# 3    Kishore        37       C8S11  Concept Test 4     0        5       0
# 4       Mano        38       C8S11  Concept Test 4     2        5       2
# 5     Nandha        39       C8S11  Concept Test 4     1        4       1
# 6   Nandhini        40       C8S11  Concept Test 4     5        5       5
# 7     Rubika        42       C8S11  Concept Test 4     3        5       3
# 8      Saila        43       C8S11  Concept Test 4     -        -       -
# 9    Shankar        44       C8S11  Concept Test 4     1        5       1
# 10     Tarun        45       C8S11  Concept Test 4     3        5       3
# 11    Thanis        46       C8S11  Concept Test 4     1        5       1
# ...

# %%
q=task[['Name','id','Chapter Tag','Concept Test 5 - score','Concept Test 5 - answered','Concept Test 5- correct','Concept Test 5- wrong','Concept Test 5- skipped','Concept Test 5 - time-taken (seconds)']]

# %%
q['Test Name']='Concept Test 5'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\4052387312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q['Test Name']='Concept Test 5'

# %%
task5=pd.melt(q,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 5 - score","Concept Test 5 - answered","Concept Test 5- correct","Concept Test 5- wrong","Concept Test 5- skipped"],value_name='Concept Test 5 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\2025907504.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task5=pd.melt(q,id_vars=["Name","id","Chapter Tag","Test Name","Concept Test 5 - score","Concept Test 5 - answered","Concept Test 5- correct","Concept Test 5- wrong","Concept Test 5- skipped"],value_name='Concept Test 5 - time-taken (seconds)')

# %%
task5
# Out:
#         Name  id Chapter Tag       Test Name Concept Test 5 - score  \
# 0    Darshan  34       C8S11  Concept Test 5                      3
# 1      Durga  35       C8S11  Concept Test 5                      4
# 2      Idhaz  36       C8S11  Concept Test 5                      3
# 3    Kishore  37       C8S11  Concept Test 5                      -
# 4       Mano  38       C8S11  Concept Test 5                      4
# 5     Nandha  39       C8S11  Concept Test 5                      4
# 6   Nandhini  40       C8S11  Concept Test 5                      4
# 7     Rubika  42       C8S11  Concept Test 5                      3
# 8      Saila  43       C8S11  Concept Test 5                      2
# 9    Shankar  44       C8S11  Concept Test 5                      5
# 10     Tarun  45       C8S11  Concept Test 5                      4
# 11    Thanis  46       C8S11  Concept Test 5                      4
# 12   Vignesh  47       C8S11  Concept Test 5                      4
#
# ...

# %%
task5=task5.rename(columns={'id':'Username','Concept Test 5 - score':'score','Concept Test 5 - answered':'answered','Concept Test 5- correct':'correct','Concept Test 5- wrong':'wrong','Concept Test 5- skipped':'skipped','Concept Test 5 - time-taken (seconds)':'time-taken'})

# %%
task5
# Out:
#         Name  Username Chapter Tag       Test Name score answered correct  \
# 0    Darshan        34       C8S11  Concept Test 5     3        5       3
# 1      Durga        35       C8S11  Concept Test 5     4        5       4
# 2      Idhaz        36       C8S11  Concept Test 5     3        5       3
# 3    Kishore        37       C8S11  Concept Test 5     -        -       -
# 4       Mano        38       C8S11  Concept Test 5     4        5       4
# 5     Nandha        39       C8S11  Concept Test 5     4        5       4
# 6   Nandhini        40       C8S11  Concept Test 5     4        5       4
# 7     Rubika        42       C8S11  Concept Test 5     3        4       3
# 8      Saila        43       C8S11  Concept Test 5     2        5       2
# 9    Shankar        44       C8S11  Concept Test 5     5        5       5
# 10     Tarun        45       C8S11  Concept Test 5     4        5       4
# 11    Thanis        46       C8S11  Concept Test 5     4        5       4
# ...

# %%
r=task[['Name','id','Chapter Tag','Topic Test 1 - score','Topic Test 1 - answered','Topic Test 1- correct','Topic Test 1- wrong','Topic Test 1- skipped','Topic Test 1 - time-taken (seconds)']]

# %%
r['Test Name']='Topic Test 1'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3638806301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r['Test Name']='Topic Test 1'

# %%
task6=pd.melt(r,id_vars=["Name","id","Chapter Tag","Test Name","Topic Test 1 - score","Topic Test 1 - answered","Topic Test 1- correct","Topic Test 1- wrong","Topic Test 1- skipped"],value_name='Topic Test 1 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3335950480.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task6=pd.melt(r,id_vars=["Name","id","Chapter Tag","Test Name","Topic Test 1 - score","Topic Test 1 - answered","Topic Test 1- correct","Topic Test 1- wrong","Topic Test 1- skipped"],value_name='Topic Test 1 - time-taken (seconds)')

# %%
task6
# Out:
#         Name  id Chapter Tag     Test Name Topic Test 1 - score  \
# 0    Darshan  34       C8S11  Topic Test 1                    5
# 1      Durga  35       C8S11  Topic Test 1                    5
# 2      Idhaz  36       C8S11  Topic Test 1                    7
# 3    Kishore  37       C8S11  Topic Test 1                    0
# 4       Mano  38       C8S11  Topic Test 1                    2
# 5     Nandha  39       C8S11  Topic Test 1                    3
# 6   Nandhini  40       C8S11  Topic Test 1                    7
# 7     Rubika  42       C8S11  Topic Test 1                    5
# 8      Saila  43       C8S11  Topic Test 1                    -
# 9    Shankar  44       C8S11  Topic Test 1                    5
# 10     Tarun  45       C8S11  Topic Test 1                    4
# 11    Thanis  46       C8S11  Topic Test 1                    4
# 12   Vignesh  47       C8S11  Topic Test 1                    3
#
# ...

# %%
task6=task6.rename(columns={'id':'Username','Topic Test 1 - score':'score','Topic Test 1 - answered':'answered','Topic Test 1- correct':'correct','Topic Test 1- wrong':'wrong','Topic Test 1- skipped':'skipped','Topic Test 1 - time-taken (seconds)':'time-taken'})

# %%
task6
# Out:
#         Name  Username Chapter Tag     Test Name score answered correct wrong  \
# 0    Darshan        34       C8S11  Topic Test 1     5       10       5     5
# 1      Durga        35       C8S11  Topic Test 1     5       10       5     5
# 2      Idhaz        36       C8S11  Topic Test 1     7       10       7     3
# 3    Kishore        37       C8S11  Topic Test 1     0        8       0     8
# 4       Mano        38       C8S11  Topic Test 1     2       10       2     8
# 5     Nandha        39       C8S11  Topic Test 1     3       10       3     7
# 6   Nandhini        40       C8S11  Topic Test 1     7       10       7     3
# 7     Rubika        42       C8S11  Topic Test 1     5        9       5     4
# 8      Saila        43       C8S11  Topic Test 1     -        -       -     -
# 9    Shankar        44       C8S11  Topic Test 1     5       10       5     5
# 10     Tarun        45       C8S11  Topic Test 1     4        9       4     5
# ...

# %%
s=task[['Name','id','Chapter Tag','Topic Test 2 - score','Topic Test 2 - answered','Topic Test 2- correct','Topic Test 2- wrong','Topic Test 2- skipped','Topic Test 2 - time-taken (seconds)']]

# %%
s['Test Name']='Topic Test 2'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3870486995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['Test Name']='Topic Test 2'

# %%
task7=pd.melt(s,id_vars=["Name","id","Chapter Tag","Test Name","Topic Test 2 - score","Topic Test 2 - answered","Topic Test 2- correct","Topic Test 2- wrong","Topic Test 2- skipped"],value_name='Topic Test 2 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\2193751327.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task7=pd.melt(s,id_vars=["Name","id","Chapter Tag","Test Name","Topic Test 2 - score","Topic Test 2 - answered","Topic Test 2- correct","Topic Test 2- wrong","Topic Test 2- skipped"],value_name='Topic Test 2 - time-taken (seconds)')

# %%
task7
# Out:
#         Name  id Chapter Tag     Test Name Topic Test 2 - score  \
# 0    Darshan  34       C8S11  Topic Test 2                    6
# 1      Durga  35       C8S11  Topic Test 2                    6
# 2      Idhaz  36       C8S11  Topic Test 2                    8
# 3    Kishore  37       C8S11  Topic Test 2                    1
# 4       Mano  38       C8S11  Topic Test 2                    5
# 5     Nandha  39       C8S11  Topic Test 2                    3
# 6   Nandhini  40       C8S11  Topic Test 2                    6
# 7     Rubika  42       C8S11  Topic Test 2                    6
# 8      Saila  43       C8S11  Topic Test 2                    -
# 9    Shankar  44       C8S11  Topic Test 2                    5
# 10     Tarun  45       C8S11  Topic Test 2                    4
# 11    Thanis  46       C8S11  Topic Test 2                    8
# 12   Vignesh  47       C8S11  Topic Test 2                    6
#
# ...

# %%
task7=task7.rename(columns={'id':'Username','Topic Test 2 - score':'score','Topic Test 2 - answered':'answered','Topic Test 2- correct':'correct','Topic Test 2- wrong':'wrong','Topic Test 2- skipped':'skipped','Topic Test 2 - time-taken (seconds)':'time-taken'})

# %%
task7
# Out:
#         Name  Username Chapter Tag     Test Name score answered correct wrong  \
# 0    Darshan        34       C8S11  Topic Test 2     6       10       6     4
# 1      Durga        35       C8S11  Topic Test 2     6        9       6     3
# 2      Idhaz        36       C8S11  Topic Test 2     8       10       8     2
# 3    Kishore        37       C8S11  Topic Test 2     1        9       1     8
# 4       Mano        38       C8S11  Topic Test 2     5       10       5     5
# 5     Nandha        39       C8S11  Topic Test 2     3       10       3     7
# 6   Nandhini        40       C8S11  Topic Test 2     6       10       6     4
# 7     Rubika        42       C8S11  Topic Test 2     6       10       6     4
# 8      Saila        43       C8S11  Topic Test 2     -        -       -     -
# 9    Shankar        44       C8S11  Topic Test 2     5       10       5     5
# 10     Tarun        45       C8S11  Topic Test 2     4        9       4     5
# ...

# %%
t=task[['Name','id','Chapter Tag','Full Chapter Test 1 - score','Full Chapter Test 1 - answered','Full Chapter Test 1- correct','Full Chapter Test 1- wrong','Full Chapter Test 1- skipped','Full Chapter Test 1 - time-taken (seconds)']]

# %%
t['Test Name']='Full Chapter Test 1'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1537677504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['Test Name']='Full Chapter Test 1'

# %%
task8=pd.melt(t,id_vars=["Name","id","Chapter Tag","Test Name","Full Chapter Test 1 - score","Full Chapter Test 1 - answered","Full Chapter Test 1- correct","Full Chapter Test 1- wrong","Full Chapter Test 1- skipped"],value_name='Full Chapter Test 1 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3379686412.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task8=pd.melt(t,id_vars=["Name","id","Chapter Tag","Test Name","Full Chapter Test 1 - score","Full Chapter Test 1 - answered","Full Chapter Test 1- correct","Full Chapter Test 1- wrong","Full Chapter Test 1- skipped"],value_name='Full Chapter Test 1 - time-taken (seconds)')

# %%
task8
# Out:
#         Name  id Chapter Tag            Test Name Full Chapter Test 1 - score  \
# 0    Darshan  34       C8S11  Full Chapter Test 1                           6
# 1      Durga  35       C8S11  Full Chapter Test 1                           4
# 2      Idhaz  36       C8S11  Full Chapter Test 1                           4
# 3    Kishore  37       C8S11  Full Chapter Test 1                           4
# 4       Mano  38       C8S11  Full Chapter Test 1                           4
# 5     Nandha  39       C8S11  Full Chapter Test 1                           2
# 6   Nandhini  40       C8S11  Full Chapter Test 1                           7
# 7     Rubika  42       C8S11  Full Chapter Test 1                           7
# 8      Saila  43       C8S11  Full Chapter Test 1                           -
# 9    Shankar  44       C8S11  Full Chapter Test 1                           4
# 10     Tarun  45       C8S11  Full Chapter Test 1                           1
# ...

# %%
task8=task8.rename(columns={'id':'Username','Full Chapter Test 1 - score':'score','Full Chapter Test 1 - answered':'answered','Full Chapter Test 1- correct':'correct','Full Chapter Test 1- wrong':'wrong','Full Chapter Test 1- skipped':'skipped','Full Chapter Test 1 - time-taken (seconds)':'time-taken'})

# %%
task8
# Out:
#         Name  Username Chapter Tag            Test Name score answered  \
# 0    Darshan        34       C8S11  Full Chapter Test 1     6       10
# 1      Durga        35       C8S11  Full Chapter Test 1     4       10
# 2      Idhaz        36       C8S11  Full Chapter Test 1     4       10
# 3    Kishore        37       C8S11  Full Chapter Test 1     4       10
# 4       Mano        38       C8S11  Full Chapter Test 1     4       10
# 5     Nandha        39       C8S11  Full Chapter Test 1     2        9
# 6   Nandhini        40       C8S11  Full Chapter Test 1     7       10
# 7     Rubika        42       C8S11  Full Chapter Test 1     7       10
# 8      Saila        43       C8S11  Full Chapter Test 1     -        -
# 9    Shankar        44       C8S11  Full Chapter Test 1     4       10
# 10     Tarun        45       C8S11  Full Chapter Test 1     1        4
# 11    Thanis        46       C8S11  Full Chapter Test 1     3       10
# ...

# %%
u=task[['Name','id','Chapter Tag','Full Chapter Test 2 - score','Full Chapter Test 2 - answered','Full Chapter Test 2- correct','Full Chapter Test 2- wrong','Full Chapter Test 2- skipped','Full Chapter Test 2 - time-taken (seconds)']]

# %%
u['Test Name']='Full Chapter Test 2'
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\3611780527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   u['Test Name']='Full Chapter Test 2'

# %%
task9=pd.melt(u,id_vars=["Name","id","Chapter Tag","Test Name","Full Chapter Test 2 - score","Full Chapter Test 2 - answered","Full Chapter Test 2- correct","Full Chapter Test 2- wrong","Full Chapter Test 2- skipped"],value_name='Full Chapter Test 2 - time-taken (seconds)')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1698256139.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   task9=pd.melt(u,id_vars=["Name","id","Chapter Tag","Test Name","Full Chapter Test 2 - score","Full Chapter Test 2 - answered","Full Chapter Test 2- correct","Full Chapter Test 2- wrong","Full Chapter Test 2- skipped"],value_name='Full Chapter Test 2 - time-taken (seconds)')

# %%
task9
# Out:
#         Name  id Chapter Tag            Test Name Full Chapter Test 2 - score  \
# 0    Darshan  34       C8S11  Full Chapter Test 2                           6
# 1      Durga  35       C8S11  Full Chapter Test 2                           6
# 2      Idhaz  36       C8S11  Full Chapter Test 2                           8
# 3    Kishore  37       C8S11  Full Chapter Test 2                           0
# 4       Mano  38       C8S11  Full Chapter Test 2                           2
# 5     Nandha  39       C8S11  Full Chapter Test 2                           0
# 6   Nandhini  40       C8S11  Full Chapter Test 2                           5
# 7     Rubika  42       C8S11  Full Chapter Test 2                           5
# 8      Saila  43       C8S11  Full Chapter Test 2                           -
# 9    Shankar  44       C8S11  Full Chapter Test 2                           2
# 10     Tarun  45       C8S11  Full Chapter Test 2                           1
# ...

# %%
task9=task9.rename(columns={'id':'Username','Full Chapter Test 2 - score':'score','Full Chapter Test 2 - answered':'answered','Full Chapter Test 2- correct':'correct','Full Chapter Test 2- wrong':'wrong','Full Chapter Test 2- skipped':'skipped','Full Chapter Test 2 - time-taken (seconds)':'time-taken'})

# %%
task9
# Out:
#         Name  Username Chapter Tag            Test Name score answered  \
# 0    Darshan        34       C8S11  Full Chapter Test 2     6       10
# 1      Durga        35       C8S11  Full Chapter Test 2     6       10
# 2      Idhaz        36       C8S11  Full Chapter Test 2     8       10
# 3    Kishore        37       C8S11  Full Chapter Test 2     0        9
# 4       Mano        38       C8S11  Full Chapter Test 2     2       10
# 5     Nandha        39       C8S11  Full Chapter Test 2     0       10
# 6   Nandhini        40       C8S11  Full Chapter Test 2     5       10
# 7     Rubika        42       C8S11  Full Chapter Test 2     5       10
# 8      Saila        43       C8S11  Full Chapter Test 2     -        -
# 9    Shankar        44       C8S11  Full Chapter Test 2     2       10
# 10     Tarun        45       C8S11  Full Chapter Test 2     1        9
# 11    Thanis        46       C8S11  Full Chapter Test 2     1       10
# ...

# %%
merged_df=pd.concat([task1,task2,task3,task4,task5,task6,task7,task8,task9],axis=0)

# %%
merged_df
# Out:
#        Name  Username Chapter Tag            Test Name answered correct score  \
# 0   Darshan        34       C8S11       Concept Test 1        4       4     4
# 1     Durga        35       C8S11       Concept Test 1        5       3     3
# 2     Idhaz        36       C8S11       Concept Test 1        5       5     5
# 3   Kishore        37       C8S11       Concept Test 1        3       1     1
# 4      Mano        38       C8S11       Concept Test 1        5       4     4
# ..      ...       ...         ...                  ...      ...     ...   ...
# 8     Saila        43       C8S11  Full Chapter Test 2        -       -     -
# 9   Shankar        44       C8S11  Full Chapter Test 2       10       2     2
# 10    Tarun        45       C8S11  Full Chapter Test 2        9       1     1
# 11   Thanis        46       C8S11  Full Chapter Test 2       10       1     1
# 12  Vignesh        47       C8S11  Full Chapter Test 2        -       -     -
#
# ...

# %%
merged_df.drop(['variable'],axis=1,inplace=True)

# %%
merged_df
# Out:
#        Name  Username Chapter Tag            Test Name answered correct score  \
# 0   Darshan        34       C8S11       Concept Test 1        4       4     4
# 1     Durga        35       C8S11       Concept Test 1        5       3     3
# 2     Idhaz        36       C8S11       Concept Test 1        5       5     5
# 3   Kishore        37       C8S11       Concept Test 1        3       1     1
# 4      Mano        38       C8S11       Concept Test 1        5       4     4
# ..      ...       ...         ...                  ...      ...     ...   ...
# 8     Saila        43       C8S11  Full Chapter Test 2        -       -     -
# 9   Shankar        44       C8S11  Full Chapter Test 2       10       2     2
# 10    Tarun        45       C8S11  Full Chapter Test 2        9       1     1
# 11   Thanis        46       C8S11  Full Chapter Test 2       10       1     1
# 12  Vignesh        47       C8S11  Full Chapter Test 2        -       -     -
#
#    skipped time-taken wrong
# ...

# %%
merged_df=merged_df.sort_values(["Name","Username","Chapter Tag","Test Name"])

# %%
merged_df
# Out:
#        Name  Username Chapter Tag            Test Name answered correct score  \
# 0   Darshan        34       C8S11       Concept Test 1        4       4     4
# 0   Darshan        34       C8S11       Concept Test 2        4       1     1
# 0   Darshan        34       C8S11       Concept Test 3        5       4     4
# 0   Darshan        34       C8S11       Concept Test 4        5       3     3
# 0   Darshan        34       C8S11       Concept Test 5        5       3     3
# ..      ...       ...         ...                  ...      ...     ...   ...
# 12  Vignesh        47       C8S11       Concept Test 5        5       4     4
# 12  Vignesh        47       C8S11  Full Chapter Test 1       10       4     4
# 12  Vignesh        47       C8S11  Full Chapter Test 2        -       -     -
# 12  Vignesh        47       C8S11         Topic Test 1       10       3     3
# 12  Vignesh        47       C8S11         Topic Test 2        9       6     6
#
#    skipped time-taken wrong
# ...

# %%
import numpy as np

# %%
merged_df['answered'].replace('-',np.nan,inplace=True)
merged_df['correct'].replace('-',np.nan,inplace=True)
merged_df['score'].replace('-',np.nan,inplace=True)
merged_df['skipped'].replace('-',np.nan,inplace=True)
merged_df['time-taken'].replace('-',np.nan,inplace=True)
merged_df['wrong'].replace('-',np.nan,inplace=True)

# %%
f_task=merged_df.dropna(axis=0)

# %%
f_task
# Out:
#        Name  Username Chapter Tag            Test Name  answered  correct  \
# 0   Darshan        34       C8S11       Concept Test 1       4.0      4.0
# 0   Darshan        34       C8S11       Concept Test 2       4.0      1.0
# 0   Darshan        34       C8S11       Concept Test 3       5.0      4.0
# 0   Darshan        34       C8S11       Concept Test 4       5.0      3.0
# 0   Darshan        34       C8S11       Concept Test 5       5.0      3.0
# ..      ...       ...         ...                  ...       ...      ...
# 12  Vignesh        47       C8S11       Concept Test 4       5.0      2.0
# 12  Vignesh        47       C8S11       Concept Test 5       5.0      4.0
# 12  Vignesh        47       C8S11  Full Chapter Test 1      10.0      4.0
# 12  Vignesh        47       C8S11         Topic Test 1      10.0      3.0
# 12  Vignesh        47       C8S11         Topic Test 2       9.0      6.0
#
#     score  skipped  time-taken  wrong
# 0     4.0      1.0       118.0    0.0
# ...

# %%
float_col = f_task.select_dtypes(include=['float64']) 

 for col in float_col.columns.values:
        f_task[col] = f_task[col].astype('int64')
# Out:
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16028\1617687213.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_task[col] = f_task[col].astype('int64')

# %%
f_task
# Out:
#        Name  Username Chapter Tag            Test Name  answered  correct  \
# 0   Darshan        34       C8S11       Concept Test 1         4        4
# 0   Darshan        34       C8S11       Concept Test 2         4        1
# 0   Darshan        34       C8S11       Concept Test 3         5        4
# 0   Darshan        34       C8S11       Concept Test 4         5        3
# 0   Darshan        34       C8S11       Concept Test 5         5        3
# ..      ...       ...         ...                  ...       ...      ...
# 12  Vignesh        47       C8S11       Concept Test 4         5        2
# 12  Vignesh        47       C8S11       Concept Test 5         5        4
# 12  Vignesh        47       C8S11  Full Chapter Test 1        10        4
# 12  Vignesh        47       C8S11         Topic Test 1        10        3
# 12  Vignesh        47       C8S11         Topic Test 2         9        6
#
#     score  skipped  time-taken  wrong
# 0       4        1         118      0
# ...
